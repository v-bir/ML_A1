# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn import preprocessing
import pandas as pd

header = ["age","workclass","fnlwgt","education","education-num",
          "marital-status","occupation","relationship","race", "sex",
         "capital-gain", "capital-loss", "hours-per-week", "native-country", "income"]
adults_raw = pd.read_csv("./Adult/adult.data", names=header)
adults_raw

adults_raw['education'].value_counts().plot(kind='bar')
adults_raw['marital-status'].value_counts().plot(kind='bar')
adults_raw.hist(bins = 50, figsize = (20,15))

# %%
enc = preprocessing.OrdinalEncoder(categories="auto", dtype=int)
enc.fit(adults_raw)
adults = enc.transform(adults_raw)
adults_input = adults[:,0:14]
adults_input
adults_target = adults[:,14]
adults_target
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
tree = tree.DecisionTreeClassifier()
tree.fit(adults_input, adults_target)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
adults_test_raw = pd.read_csv("./Adult/adult.test", names=header)
adults_test_raw
enc_test = preprocessing.OrdinalEncoder(categories="auto", dtype=int)
enc_test.fit(adults_test_raw)
adults_test = enc_test.transform(adults_test_raw)
adults_target_test = adults_test[:,14]
adults_input_test = adults_test[:,0:14]

# %%
tree.score(adults_input_test, adults_target_test)
# Out:
# 0.8018549229162828

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

prediction = tree.predict(adults_input_test)
cnf_matrix = confusion_matrix(adults_target_test, prediction)
print(cnf_matrix)

print("Accuracy:\t %.3f" % accuracy_score(adults_target_test, prediction))
print("Precision:\t %.3f" % precision_score(adults_target_test, prediction))
print("Sensitivity:\t %.3f" % recall_score(adults_target_test, prediction))
print("F1:\t\t %.3f" % f1_score(adults_target_test, prediction))
# Out:
# [[10807  1628]
#  [ 1598  2248]]
# Accuracy:	 0.802
# Precision:	 0.580
# Sensitivity:	 0.585
# F1:		 0.582

# %%
from sklearn.ensemble import RandomForestClassifier

rand_forest = RandomForestClassifier(n_estimators = 100)
rand_forest.fit(adults_input, adults_target)
rand_forest.score(adults_input_test, adults_target_test)

prediction = rand_forest.predict(adults_input_test)
cnf_matrix = confusion_matrix(adults_target_test, prediction)
print(cnf_matrix)

print("Accuracy:\t %.3f" % accuracy_score(adults_target_test, prediction))
print("Precision:\t %.3f" % precision_score(adults_target_test, prediction))
print("Sensitivity:\t %.3f" % recall_score(adults_target_test, prediction))
print("F1:\t\t %.3f" % f1_score(adults_target_test, prediction))
# Out:
# [[11666   769]
#  [ 1651  2195]]
# Accuracy:	 0.851
# Precision:	 0.741
# Sensitivity:	 0.571
# F1:		 0.645
